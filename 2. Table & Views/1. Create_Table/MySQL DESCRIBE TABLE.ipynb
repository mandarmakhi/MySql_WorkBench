# %% [markdown]
# # MySQL DESCRIBE TABLE
#
# ![mysql-describe-table6.png](attachment:mysql-describe-table6.png)
# ![mysql-describe-table7.png](attachment:mysql-describe-table7.png)
# ![mysql-describe-table8.png](attachment:mysql-describe-table8.png)
# ![mysql-describe-table9.png](attachment:mysql-describe-table9.png)
# ![mysql-describe-table10.png](attachment:mysql-describe-table10.png)
